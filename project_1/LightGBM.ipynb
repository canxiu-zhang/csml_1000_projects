# %% [markdown]
# # Import packages

# %%
import pandas as pd
import numpy as np
from pycaret.classification import *
from imblearn.under_sampling import RandomUnderSampler
import shap
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

# %% [markdown]
# # Preprocessing

# %%
dataset = pd.read_csv('data.csv')

# %% [markdown]
# ## Data Quality Assessment
# missing value - NA\
# inconsistent value\
# duplicate value\
# outlier\
# imbalanced: Bankrupt? - 1: 3.2%(220), 0: 96.8%(6599)\
# zeros: Liability-Assets Flag - 1: 0.01%(8), 0: 99.9%(6811)\
# constant values: Net Income Flag (value=1)

# %%
# check Liability-Assets Flag
df = dataset[dataset[" Liability-Assets Flag"]==1]
df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 56            1                                           0.066933
# 1869          1                                           0.392775
# 1870          1                                           0.277726
# 2001          1                                           0.438795
# 2470          1                                           0.404036
# 2735          0                                           0.436894
# 6613          0                                           0.279676
# 6640          1                                           0.196802
#
#        ROA(A) before interest and % after tax  \
# 56                                   0.057185
# 1869                                 0.432239
# 1870                                 0.314708
# 2001                                 0.090166
# 2470                                 0.223615
# 2735                                 0.453718
# 6613                                 0.283362
# 6640                                 0.211023
#
#        ROA(B) before interest and depreciation after tax  \
# 56                                             0.054821
# 1869                                           0.432946
# 1870                                           0.307351
# 2001                                           0.464586
# 2470                                           0.430055
# 2735                                           0.479522
# 6613                                           0.303014
# 6640                                           0.221425
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 56                   0.601861                      0.601861
# 1869                 0.586921                      0.586921
# 1870                 0.596621                      0.596650
# 2001                 0.540776                      0.540776
# 2470                 0.586611                      0.586611
# 2735                 0.585062                      0.585062
# 6613                 0.637520                      0.637520
# 6640                 0.598056                      0.598056
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 56                  0.998825                    0.796779
# 1869                0.998776                    0.797126
# 1870                0.998976                    0.797176
# 2001                0.997789                    0.790787
# 2470                0.998568                    0.796179
# 2735                0.998495                    0.796770
# 6613                0.998785                    0.797055
# 6640                0.998933                    0.796144
#
#        After-tax net Interest Rate  \
# 56                        0.808717
# 1869                      0.809068
# 1870                      0.809113
# 2001                      0.802967
# 2470                      0.808154
# 2735                      0.808785
# 6613                      0.809000
# 6640                      0.808149
#
#        Non-industry income and expenditure/revenue  \
# 56                                        0.302760
# 1869                                      0.303470
# 1870                                      0.303138
# 2001                                      0.294457
# 2470                                      0.302249
# 2735                                      0.303434
# 6613                                      0.303325
# 6640                                      0.301423
#
#        Continuous interest rate (after tax)   Operating Expense Rate  \
# 56                                 0.780927             2.766025e-04
# 1869                               0.781325             8.640000e+09
# 1870                               0.781360             4.210000e+09
# 2001                               0.780105             3.329175e-04
# 2470                               0.781061             2.890912e-04
# 2735                               0.781002             3.374273e-04
# 6613                               0.781234             8.888977e-04
# 6640                               0.780388             1.068481e-04
#
#        Research and development expense rate   Cash flow rate  \
# 56                              1.150000e+08         0.458264
# 1869                            6.600000e+09         0.461523
# 1870                            9.680000e+08         0.452861
# 2001                            3.156310e-04         0.461074
# 2470                            0.000000e+00         0.457979
# 2735                            0.000000e+00         0.459881
# 6613                            0.000000e+00         0.461433
# 6640                            1.880000e+09         0.472751
#
#        Interest-bearing debt interest rate   Tax rate (A)  \
# 56                            3.990399e-04            0.0
# 1869                          2.160216e-04            0.0
# 1870                          2.200220e-04            0.0
# 2001                          2.400240e-04            0.0
# 2470                          3.640364e-04            0.0
# 2735                          9.800000e+08            0.0
# 6613                          0.000000e+00            0.0
# 6640                          2.340234e-04            0.0
#
#        Net Value Per Share (B)   Net Value Per Share (A)  \
# 56                    0.120012                  0.120012
# 1869                  0.120180                  0.120180
# 1870                  0.102398                  0.102398
# 2001                  0.120602                  0.120602
# 2470                  0.116599                  0.116599
# 2735                  0.121613                  0.121613
# 6613                  0.000000                  0.000000
# 6640                  0.069656                  0.069656
#
#        Net Value Per Share (C)   Persistent EPS in the Last Four Seasons  \
# 56                    0.120012                                  0.084239
# 1869                  0.120180                                  0.115061
# 1870                  0.102398                                  0.000000
# 2001                  0.120602                                  0.190224
# 2470                  0.116599                                  0.173301
# 2735                  0.121613                                  0.188617
# 6613                  0.000000                                  0.180297
# 6640                  0.069656                                  0.079512
#
#        Cash Flow Per Share   Revenue Per Share (Yuan ¥)  \
# 56                0.308481                     0.045843
# 1869              0.319021                     0.093244
# 1870              0.208460                     0.235976
# 2001              0.316793                     0.003721
# 2470              0.311417                     0.018361
# 2735              0.311594                     0.010285
# 6613              0.317995                     0.023247
# 6640              0.340348                     0.025757
#
#        Operating Profit Per Share (Yuan ¥)  \
# 56                                0.066200
# 1869                              0.014820
# 1870                              0.111799
# 2001                              0.074912
# 2470                              0.061559
# 2735                              0.072877
# 6613                              0.076134
# 6640                              0.091931
#
#        Per Share Net profit before tax (Yuan ¥)  \
# 56                                     0.067485
# 1869                                   0.084884
# 1870                                   0.000000
# 2001                                   0.079461
# 2470                                   0.085561
# 2735                                   0.147322
# 6613                                   0.142728
# 6640                                   0.054304
#
#        Realized Sales Gross Profit Growth Rate   Operating Profit Growth Rate  \
# 56                                    0.022166                       0.847569
# 1869                                  0.020457                       0.848062
# 1870                                  0.022067                       0.847971
# 2001                                  0.021378                       0.736430
# 2470                                  0.021732                       0.843895
# 2735                                  0.022216                       0.848101
# 6613                                  0.033310                       0.848090
# 6640                                  0.021974                       0.847908
#
#        After-tax Net Profit Growth Rate   Regular Net Profit Growth Rate  \
# 56                             0.686085                         0.686085
# 1869                           0.689515                         0.689515
# 1870                           0.686572                         0.686572
# 2001                           0.534824                         0.534824
# 2470                           0.684855                         0.684855
# 2735                           0.689567                         0.689567
# 6613                           0.689453                         0.689453
# 6640                           0.687915                         0.687915
#
#        Continuous Net Profit Growth Rate   Total Asset Growth Rate  \
# 56                              0.216971              7.230000e+09
# 1869                            0.217608              4.220000e+09
# 1870                            0.217275              6.290000e+09
# 2001                            0.214354              2.490000e+08
# 2470                            0.217416              4.120000e+09
# 2735                            0.217613              5.860000e+08
# 6613                            0.217600              3.133957e-04
# 6640                            0.217439              2.590000e+09
#
#        Net Value Growth Rate   Total Asset Return Growth Rate Ratio  \
# 56              1.542430e-04                               0.256152
# 1869            1.649235e-04                               0.264689
# 1870            1.217524e-04                               0.260527
# 2001            1.670197e-04                               0.259243
# 2470            9.330000e+09                               0.260341
# 2735            1.350000e+09                               0.265399
# 6613            4.103998e-04                               0.266008
# 6640            0.000000e+00                               0.259533
#
#        Cash Reinvestment %   Current Ratio   Quick Ratio  \
# 56                0.327158        0.004329      0.003309
# 1869              0.422684        0.005246      0.002870
# 1870              1.000000        0.005096      0.003948
# 2001              0.370068        0.000719      0.000709
# 2470              0.365169        0.001261      0.000763
# 2735              0.319493        0.000000      0.000165
# 6613              0.375768        0.000689      0.000868
# 6640              0.432426        0.004788      0.002362
#
#        Interest Expense Ratio   Total debt/Total net worth   Debt ratio %  \
# 56                   0.630523                     0.126572       0.321371
# 1869                 0.630306                     0.378620       0.305378
# 1870                 0.630492                     0.103998       0.326934
# 2001                 0.630547                     0.090127       0.331892
# 2470                 0.630462                     0.076939       0.338483
# 2735                 0.630437                     0.194535       0.312755
# 6613                 0.630612                     0.012911       1.000000
# 6640                 0.630536                     0.021102       0.525410
#
#        Net worth/Assets   Long-term fund suitability ratio (A)  \
# 56             0.678629                               0.004902
# 1869           0.694622                               0.004129
# 1870           0.673066                               0.004171
# 2001           0.668108                               0.004676
# 2470           0.661517                               0.004877
# 2735           0.687245                               0.004700
# 6613           0.000000                               0.000000
# 6640           0.474590                               0.004477
#
#        Borrowing dependency   Contingent liabilities/Net worth  \
# 56                 0.262035                           0.000633
# 1869               0.000000                           0.005366
# 1870               0.270743                           0.005366
# 2001               0.279725                           0.005366
# 2470               0.295894                           0.004445
# 2735               0.187124                           0.005366
# 6613               0.357440                           0.005366
# 6640               0.357056                           0.000000
#
#        Operating profit/Paid-in capital  \
# 56                             0.066996
# 1869                           0.014787
# 1870                           0.111364
# 2001                           0.074886
# 2470                           0.061581
# 2735                           0.072858
# 6613                           0.076148
# 6640                           0.092009
#
#        Net profit before tax/Paid-in capital  \
# 56                                  0.072453
# 1869                                0.083787
# 1870                                0.000000
# 2001                                0.080605
# 2470                                0.089465
# 2735                                0.146316
# 6613                                0.141701
# 6640                                0.057130
#
#        Inventory and accounts receivable/Net value   Total Asset Turnover  \
# 56                                        0.351419               0.292354
# 1869                                      0.000000               0.157421
# 1870                                      0.283785               0.410795
# 2001                                      0.384007               0.025487
# 2470                                      0.390738               0.098951
# 2735                                      0.390443               0.055472
# 6613                                      0.391744               0.289355
# 6640                                      0.391550               0.100450
#
#        Accounts Receivable Turnover   Average Collection Days  \
# 56                         0.001311                  0.004827
# 1869                       0.000528                  0.011999
# 1870                       0.000982                  0.006444
# 2001                       0.000639                  0.009888
# 2470                       0.003133                  0.002019
# 2735                       0.023424                  0.000270
# 6613                       0.001142                  0.005539
# 6640                       0.000684                  0.009255
#
#        Inventory Turnover Rate (times)   Fixed Assets Turnover Frequency  \
# 56                        5.042417e-04                      6.990039e-04
# 1869                      8.220000e+09                      3.739368e-03
# 1870                      2.397967e-04                      4.177381e-03
# 2001                      1.948945e-04                      1.970000e+09
# 2470                      1.910000e+07                      8.550000e+09
# 2735                      7.908513e-04                      3.180000e+08
# 6613                      1.888948e-03                      1.031863e-03
# 6640                      2.224090e-04                      1.739945e-04
#
#        Net Worth Turnover Rate (times)   Revenue per person  \
# 56                            0.161613             0.048053
# 1869                          0.235484             0.118564
# 1870                          0.396129             0.128335
# 2001                          0.017903             0.007764
# 2470                          0.139677             0.017355
# 2735                          0.676613             0.006239
# 6613                          0.000000             0.006445
# 6640                          0.158871             0.068422
#
#        Operating profit per person   Allocation rate per person  \
# 56                        0.370209                     0.009526
# 1869                      0.318842                     0.001901
# 1870                      0.398374                     0.003906
# 2001                      0.361616                     0.042332
# 2470                      0.369225                     0.023842
# 2735                      0.382239                     0.024103
# 6613                      0.388153                     0.001259
# 6640                      0.385756                     0.032154
#
#        Working Capital to Total Assets   Quick Assets/Total Assets  \
# 56                            0.692375                    0.566755
# 1869                          0.720058                    0.555111
# 1870                          0.709948                    0.806118
# 2001                          0.494210                    0.147607
# 2470                          0.643091                    0.129527
# 2735                          0.475181                    0.035045
# 6613                          0.000000                    0.526010
# 6640                          0.723172                    0.403606
#
#        Current Assets/Total Assets   Cash/Total Assets  \
# 56                        0.604127            0.210915
# 1869                      0.885585            0.093115
# 1870                      0.943633            0.027731
# 2001                      0.176471            0.089599
# 2470                      0.124091            0.015737
# 2735                      0.044384            0.031474
# 6613                      0.511293            0.102118
# 6640                      0.434591            0.024764
#
#        Quick Assets/Current Liability   Cash/Current Liability  \
# 56                       4.004091e-03                 0.004437
# 1869                     3.185487e-03                 0.001607
# 1870                     4.261677e-03                 0.000437
# 2001                     6.631787e-04                 0.001387
# 2470                     1.399524e-03                 0.000521
# 2735                     7.540000e+09                 0.000516
# 6613                     8.139498e-04                 0.000543
# 6640                     4.374054e-03                 0.000792
#
#        Current Liability to Assets   Operating Funds to Liability  \
# 56                        0.252298                       0.333539
# 1869                      0.307686                       0.341056
# 1870                      0.336844                       0.315183
# 2001                      0.343143                       0.339719
# 2470                      0.160152                       0.335961
# 2735                      0.323917                       0.336138
# 6613                      1.000000                       0.340788
# 6640                      0.165715                       0.351106
#
#        Inventory/Working Capital   Inventory/Current Liability  \
# 56                      0.276830                  1.196316e-03
# 1869                    0.275378                  5.676092e-03
# 1870                    0.276394                  2.511576e-03
# 2001                    0.276956                  5.044681e-04
# 2470                    0.276975                  0.000000e+00
# 2735                    0.276969                  1.647657e-04
# 6613                    0.276974                  3.640000e+09
# 6640                    0.276734                  1.425819e-03
#
#        Current Liabilities/Liability   Working Capital/Equity  \
# 56                          0.754574                 0.762552
# 1869                        0.972029                 0.782322
# 1870                        0.995158                 0.749179
# 2001                        0.998848                 0.825197
# 2470                        0.449042                 0.764645
# 2735                        0.999817                 0.961070
# 6613                        0.973331                 0.745133
# 6640                        0.295239                 0.733395
#
#        Current Liabilities/Equity   Long-term Liability to Current Assets  \
# 56                       0.241053                                0.011706
# 1869                     0.000000                                0.000000
# 1870                     0.234391                                0.000000
# 2001                     0.246325                                0.000000
# 2470                     0.294906                                0.123090
# 2735                     0.153811                                0.000000
# 6613                     0.314913                                0.000000
# 6640                     0.320395                                0.038191
#
#        Retained Earnings to Total Assets   Total income/Total expense  \
# 56                              0.841966                     0.002003
# 1869                            0.907144                     0.001883
# 1870                            0.888249                     0.002017
# 2001                            0.804014                     0.001903
# 2470                            0.843977                     0.001928
# 2735                            0.863099                     0.001892
# 6613                            0.592447                     0.002152
# 6640                            0.777637                     0.001996
#
#        Total expense/Assets   Current Asset Turnover Rate  \
# 56                 0.203706                  7.630000e+09
# 1869               0.036072                  1.842300e-04
# 1870               0.104957                  8.100000e+07
# 2001               0.200451                  1.924438e-04
# 2470               0.126337                  3.130000e+09
# 2735               0.024552                  2.270000e+09
# 6613               0.197692                  1.052074e-04
# 6640               0.202040                  1.116122e-04
#
#        Quick Asset Turnover Rate   Working capitcal Turnover Rate  \
# 56                  7.650000e+09                         0.593893
# 1869                1.162860e-04                         0.593897
# 1870                7.280000e+09                         0.593904
# 2001                1.660878e-04                         0.593187
# 2470                3.890000e+09                         0.593819
# 2735                2.160000e+09                         0.593406
# 6613                1.144902e-04                         0.593477
# 6640                1.085847e-04                         0.593895
#
#        Cash Turnover Rate   Cash Flow to Sales   Fixed Assets to Assets  \
# 56           8.190000e+09             0.671591                 0.222815
# 1869         5.400000e+09             0.671542                 0.012076
# 1870         7.280000e+08             0.671571                 0.050611
# 2001         2.629237e-04             0.671101                 0.810375
# 2470         1.450000e+09             0.671554                 0.652032
# 2735         6.010000e+09             0.671582                 0.882981
# 6613         6.150000e+08             0.671592                 0.141475
# 6640         1.840000e+09             0.671572                 0.275408
#
#        Current Liability to Liability   Current Liability to Equity  \
# 56                           0.754574                      0.241053
# 1869                         0.972029                      0.000000
# 1870                         0.995158                      0.234391
# 2001                         0.998848                      0.246325
# 2470                         0.449042                      0.294906
# 2735                         0.999817                      0.153811
# 6613                         0.973331                      0.314913
# 6640                         0.295239                      0.320395
#
#        Equity to Long-term Liability   Cash Flow to Total Assets  \
# 56                          0.025851                    0.705153
# 1869                        0.110933                    0.574914
# 1870                        0.110933                    0.634720
# 2001                        0.110933                    0.435125
# 2470                        0.000000                    0.617235
# 2735                        0.110933                    0.649341
# 6613                        0.110933                    0.685924
# 6640                        0.090263                    0.641957
#
#        Cash Flow to Liability   CFO to Assets   Cash Flow to Equity  \
# 56                   0.464287        0.491813              0.240450
# 1869                 0.453512        0.568591              0.569231
# 1870                 0.458624        0.299383              0.322466
# 2001                 0.443057        0.554803              0.485367
# 2470                 0.457308        0.514097              0.332253
# 2735                 0.459805        0.519647              0.302513
# 6613                 0.460398        0.569253              0.312856
# 6640                 0.459226        0.738860              0.314685
#
#        Current Liability to Current Assets   Liability-Assets Flag  \
# 56                                0.065286                       1
# 1869                              0.054445                       1
# 1870                              0.055966                       1
# 2001                              0.296636                       1
# 2470                              0.193950                       1
# 2735                              1.000000                       1
# 6613                              0.305792                       1
# 6640                              0.059374                       1
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 56                       0.525651                5.803037e-03
# 1869                     0.722761                2.417803e-03
# 1870                     0.664814                3.231135e-03
# 2001                     0.411809                1.109791e-02
# 2470                     0.572881                8.658754e-03
# 2735                     0.747290                4.202211e-04
# 6613                     0.705559                3.030000e+09
# 6640                     0.519388                1.758765e-02
#
#        No-credit Interval   Gross Profit to Sales  \
# 56               0.623648                0.601857
# 1869             0.622734                0.586923
# 1870             0.623270                0.596619
# 2001             0.625487                0.540775
# 2470             0.623173                0.586607
# 2735             0.557613                0.585059
# 6613             0.623292                0.637516
# 6640             0.623465                0.598051
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 56                               1.000000              0.182790
# 1869                             0.976180              0.000000
# 1870                             0.902744              0.199162
# 2001                             0.996912              0.209222
# 2470                             0.916329              0.218785
# 2735                             0.885473              0.133503
# 6613                             0.841826              0.265220
# 6640                             0.856906              0.259280
#
#        Degree of Financial Leverage (DFL)  \
# 56                               0.026763
# 1869                             0.026703
# 1870                             0.026755
# 2001                             0.026779
# 2470                             0.026745
# 2735                             0.026744
# 6613                             0.026791
# 6640                             0.026769
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 56                                             0.565021                   1
# 1869                                           0.564698                   1
# 1870                                           0.564978                   1
# 2001                                           0.565098                   1
# 2470                                           0.564930                   1
# 2735                                           0.564922                   1
# 6613                                           0.565158                   1
# 6640                                           0.565052                   1
#
#        Equity to Liability
# 56                0.009178
# 1869              0.009879
# 1870              0.008950
# 2001              0.008753
# 2470              0.008500
# 2735              0.009546
# 6613              0.000000
# 6640              0.003946

# %%
# drop constant feature
dataset = dataset.drop(columns=[" Net Income Flag"])

# %% [markdown]
# ## Data partition

# %%
data, data_unseen = train_test_split(dataset, test_size=0.1, random_state=42, stratify=dataset["Bankrupt?"])

# %%
data_unseen.shape
# Out:
# (682, 96)

# %%
data_unseen[data_unseen["Bankrupt?"]==1].shape
# Out:
# (22, 96)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Compare models

# %%
numeric_features = data.columns.values.tolist()
numeric_features.remove("Bankrupt?")
ru = RandomUnderSampler(random_state=123)
clf = setup(data = data, 
            target = 'Bankrupt?',
            numeric_features = numeric_features,
            session_id=888, 
            remove_multicollinearity = True,
            normalize = True,
            pca = True,
            pca_components = 0.99,
            feature_selection = True, 
            feature_selection_threshold = 0.1,
            fix_imbalance=True, 
            fix_imbalance_method=ru,
            data_split_stratify = True,
            fold_shuffle = True)
# Out:
# <style type="text/css">
# #T_148cd_row29_col1, #T_148cd_row33_col1, #T_148cd_row42_col1, #T_148cd_row44_col1, #T_148cd_row52_col1, #T_148cd_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_148cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_148cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_148cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_148cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_148cd_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_148cd_row0_col1" class="data row0 col1" >888</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_148cd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_148cd_row1_col1" class="data row1 col1" >Bankrupt?</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_148cd_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_148cd_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_148cd_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_148cd_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_148cd_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_148cd_row4_col1" class="data row4 col1" >(6137, 96)</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_148cd_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_148cd_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_148cd_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_148cd_row6_col1" class="data row6 col1" >95</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_148cd_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_148cd_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_148cd_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_148cd_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_148cd_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_148cd_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_148cd_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_148cd_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_148cd_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_148cd_row11_col1" class="data row11 col1" >(4295, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_148cd_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_148cd_row12_col1" class="data row12 col1" >(1842, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_148cd_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_148cd_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_148cd_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_148cd_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_148cd_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_148cd_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_148cd_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_148cd_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_148cd_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_148cd_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_148cd_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_148cd_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_148cd_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_148cd_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_148cd_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_148cd_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_148cd_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_148cd_row21_col1" class="data row21 col1" >cd98</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_148cd_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_148cd_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_148cd_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_148cd_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_148cd_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_148cd_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_148cd_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_148cd_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_148cd_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_148cd_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_148cd_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_148cd_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_148cd_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_148cd_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_148cd_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_148cd_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_148cd_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T

# %%
best_model=compare_models(sort = 'Prec.')
# Out:
# <style type="text/css">
# #T_53c51 th {
#   text-align: left;
# }
# #T_53c51_row0_col0, #T_53c51_row0_col1, #T_53c51_row0_col2, #T_53c51_row0_col3, #T_53c51_row1_col0, #T_53c51_row1_col1, #T_53c51_row1_col2, #T_53c51_row1_col3, #T_53c51_row1_col4, #T_53c51_row1_col5, #T_53c51_row1_col6, #T_53c51_row1_col7, #T_53c51_row2_col0, #T_53c51_row2_col1, #T_53c51_row2_col2, #T_53c51_row2_col3, #T_53c51_row2_col4, #T_53c51_row2_col5, #T_53c51_row2_col6, #T_53c51_row2_col7, #T_53c51_row3_col0, #T_53c51_row3_col1, #T_53c51_row3_col2, #T_53c51_row3_col3, #T_53c51_row3_col4, #T_53c51_row3_col5, #T_53c51_row3_col6, #T_53c51_row3_col7, #T_53c51_row4_col0, #T_53c51_row4_col1, #T_53c51_row4_col2, #T_53c51_row4_col3, #T_53c51_row4_col4, #T_53c51_row4_col5, #T_53c51_row4_col6, #T_53c51_row4_col7, #T_53c51_row5_col0, #T_53c51_row5_col1, #T_53c51_row5_col2, #T_53c51_row5_col3, #T_53c51_row5_col4, #T_53c51_row5_col5, #T_53c51_row5_col6, #T_53c51_row5_col7, #T_53c51_row6_col0, #T_53c51_row6_col1, #T_53c51_row6_col2, #T_53c51_row6_col4, #T_53c51_row6_col5, #T_53c51_row6_col6, #T_53c51_row6_col7, #T_53c51_row7_col0, #T_53c51_row7_col1, #T_53c51_row7_col2, #T_53c51_row7_col3, #T_53c51_row7_col4, #T_53c51_row7_col5, #T_53c51_row7_col6, #T_53c51_row7_col7, #T_53c51_row8_col0, #T_53c51_row8_col1, #T_53c51_row8_col3, #T_53c51_row8_col4, #T_53c51_row8_col5, #T_53c51_row8_col6, #T_53c51_row8_col7, #T_53c51_row9_col0, #T_53c51_row9_col1, #T_53c51_row9_col2, #T_53c51_row9_col3, #T_53c51_row9_col4, #T_53c51_row9_col5, #T_53c51_row9_col6, #T_53c51_row9_col7, #T_53c51_row10_col0, #T_53c51_row10_col1, #T_53c51_row10_col2, #T_53c51_row10_col3, #T_53c51_row10_col4, #T_53c51_row10_col5, #T_53c51_row10_col6, #T_53c51_row10_col7, #T_53c51_row11_col0, #T_53c51_row11_col1, #T_53c51_row11_col2, #T_53c51_row11_col3, #T_53c51_row11_col4, #T_53c51_row11_col5, #T_53c51_row11_col6, #T_53c51_row11_col7, #T_53c51_row12_col0, #T_53c51_row12_col1, #T_53c51_row12_col2, #T_53c51_row12_col3, #T_53c51_row12_col4, #T_53c51_row12_col5, #T_53c51_row12_col6, #T_53c51_row12_col7, #T_53c51_row13_col0, #T_53c51_row13_col2, #T_53c51_row13_col3, #T_53c51_row13_col4, #T_53c51_row13_col5, #T_53c51_row13_col6, #T_53c51_row13_col7 {
#   text-align: left;
# }
# #T_53c51_row0_col4, #T_53c51_row0_col5, #T_53c51_row0_col6, #T_53c51_row0_col7, #T_53c51_row6_col3, #T_53c51_row8_col2, #T_53c51_row13_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_53c51_row0_col8, #T_53c51_row1_col8, #T_53c51_row2_col8, #T_53c51_row3_col8, #T_53c51_row4_col8, #T_53c51_row5_col8, #T_53c51_row6_col8, #T_53c51_row7_col8, #T_53c51_row8_col8, #T_53c51_row9_col8, #T_53c51_row10_col8, #T_53c51_row11_col8, #T_53c51_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_53c51_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_53c51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53c51_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_53c51_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_53c51_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_53c51_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_53c51_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_53c51_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_53c51_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_53c51_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_53c51_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53c51_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_53c51_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_53c51_row0_col1" class="data row0 col1" >0.8636</td>
#       <td id="T_53c51_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_53c51_row0_col3" class="data row0 col3" >0.8495</td>
#       <td id="T_53c51_row0_col4" class="data row0 col4" >0.1745</td>
#       <td id="T_53c51_row0_col5" class="data row0 col5" >0.2892</td>
#       <td id="T_53c51_row0_col6" class="data row0 col6" >0.2488</td>
#       <td id="T_53c51_row0_col7" class="data row0 col7" >0.3467</td>
#       <td id="T_53c51_row0_col8" class="data row0 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_53c51_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_53c51_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_53c51_row1_col1" class="data row1 col1" >0.8633</td>
#       <td id="T_53c51_row1_col2" class="data row1 col2" >0.9104</td>
#       <td id="T_53c51_row1_col3" class="data row1 col3" >0.8495</td>
#       <td id="T_53c51_row1_col4" class="data row1 col4" >0.1742</td>
#       <td id="T_53c51_row1_col5" class="data row1 col5" >0.2888</td>
#       <td id="T_53c51_row1_col6" class="data row1 col6" >0.2483</td>
#       <td id="T_53c51_row1_col7" class="data row1 col7" >0.3463</td>
#       <td id="T_53c51_row1_col8" class="data row1 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_53c51_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_53c51_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_53c51_row2_col1" class="data row2 col1" >0.8538</td>
#       <td id="T_53c51_row2_col2" class="data row2 col2" >0.8969</td>
#       <td id="T_53c51_row2_col3" class="data row2 col3" >0.8060</td>
#       <td id="T_53c51_row2_col4" class="data row2 col4" >0.1598</td>
#       <td id="T_53c51_row2_col5" class="data row2 col5" >0.2662</td>
#       <td id="T_53c51_row2_col6" class="data row2 col6" >0.2243</td>
#       <td id="T_53c51_row2_col7" class="data row2 col7" >0.3170</td>
#       <td id="T_53c51_row2_col8" class="data row2 col8" >0.7690</td>
#     </tr>
#     <tr>
#       <th id="T_53c51_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_53c51_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_53c51_row3_col1" class="data row3 col1" >0.8375</td>
#       <td id="T_53c51_row3_col2" class="data row3 col2" >0.9102</td>
#       <td id="T_53c51_row3_col3" class="data row3 col3" >0.8929</td>
#       <td id="T_53c51_row3_col4" class="data row3 col4" >0.1546</td>
#       <td id="T_53c51_row3_col5" class="data row3 col5" >0.2633</td>
#       <td id="T_53c51_row3_col6" class="data row3 col6" >0.2203</td>
#       <td id="T_53c51_row3_col7" class="data row3 col7" >0.3307</td>
#       <td id="T_53c51_row3_col8" class="data row3 col8" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_53c51_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_53c51_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_53c51_row4_col1" class="data row4 col1" >0.9006</td>
#       <td id="T_53c51_row4_col2" class="data row4 col2" >0.8566</td>
#       <td id="T_53c51_row4_col3" class="data row4 col3" >0.4626</td>
#       <td id="T_53c51_row4_col4" class="data row4 col4" >0.1540</td>
#       <td id="T_53c51_row4_col5" class="data row4 col5" >0.2296</td>
#       <td id="T_53c51_row4_col6" class="data row4 col6" >0.1906</td>
#       <td id="T_53c51_row4_col7" class="data row4 col7" >0.2249</td>
#       <td id="T_53c51_row4_col8" class="data row4 col8" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_53c51_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_53c51_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_53c51_row5_col1" class="data row5 col1" >0.8324</td>
#       <td id="T_53c51_row5_col2" class="data row5 col2" >0.9214</td>
#       <td id="T_53c51_row5_col3" class="data row5 col3" >0.8714</td>
#       <td id="T_53c51_row5_col4" class="data row5 col4" >0.1483</td>
#       <td id="T_53c51_row5_col5" class="data row5 col5" >0.2532</td>
#       <td id="T_53c51_row5_col6" class="data row5 col6" >0.2095</td>
#       <td id="T_53c51_row5_col7" class="data row5 col7" >0.3169</td>
#       <td id="

# %%
lightgbm = create_model('lightgbm', return_train_score = True)
# Out:
# <style type="text/css">
# #T_80e58_row20_col0, #T_80e58_row20_col1, #T_80e58_row20_col2, #T_80e58_row20_col3, #T_80e58_row20_col4, #T_80e58_row20_col5, #T_80e58_row20_col6, #T_80e58_row22_col0, #T_80e58_row22_col1, #T_80e58_row22_col2, #T_80e58_row22_col3, #T_80e58_row22_col4, #T_80e58_row22_col5, #T_80e58_row22_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_80e58">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80e58_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_80e58_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_80e58_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_80e58_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_80e58_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_80e58_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_80e58_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80e58_level0_row0" class="row_heading level0 row0" rowspan="10">CV-Train</th>
#       <th id="T_80e58_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_80e58_row0_col0" class="data row0 col0" >0.8427</td>
#       <td id="T_80e58_row0_col1" class="data row0 col1" >0.9702</td>
#       <td id="T_80e58_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_80e58_row0_col3" class="data row0 col3" >0.1705</td>
#       <td id="T_80e58_row0_col4" class="data row0 col4" >0.2914</td>
#       <td id="T_80e58_row0_col5" class="data row0 col5" >0.2499</td>
#       <td id="T_80e58_row0_col6" class="data row0 col6" >0.3779</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_80e58_row1_col0" class="data row1 col0" >0.8515</td>
#       <td id="T_80e58_row1_col1" class="data row1 col1" >0.9691</td>
#       <td id="T_80e58_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_80e58_row1_col3" class="data row1 col3" >0.1788</td>
#       <td id="T_80e58_row1_col4" class="data row1 col4" >0.3034</td>
#       <td id="T_80e58_row1_col5" class="data row1 col5" >0.2630</td>
#       <td id="T_80e58_row1_col6" class="data row1 col6" >0.3891</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_80e58_row2_col0" class="data row2 col0" >0.8375</td>
#       <td id="T_80e58_row2_col1" class="data row2 col1" >0.9659</td>
#       <td id="T_80e58_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_80e58_row2_col3" class="data row2 col3" >0.1660</td>
#       <td id="T_80e58_row2_col4" class="data row2 col4" >0.2847</td>
#       <td id="T_80e58_row2_col5" class="data row2 col5" >0.2427</td>
#       <td id="T_80e58_row2_col6" class="data row2 col6" >0.3717</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_80e58_row3_col0" class="data row3 col0" >0.8349</td>
#       <td id="T_80e58_row3_col1" class="data row3 col1" >0.9597</td>
#       <td id="T_80e58_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_80e58_row3_col3" class="data row3 col3" >0.1638</td>
#       <td id="T_80e58_row3_col4" class="data row3 col4" >0.2815</td>
#       <td id="T_80e58_row3_col5" class="data row3 col5" >0.2393</td>
#       <td id="T_80e58_row3_col6" class="data row3 col6" >0.3686</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_80e58_row4_col0" class="data row4 col0" >0.8660</td>
#       <td id="T_80e58_row4_col1" class="data row4 col1" >0.9695</td>
#       <td id="T_80e58_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_80e58_row4_col3" class="data row4 col3" >0.1944</td>
#       <td id="T_80e58_row4_col4" class="data row4 col4" >0.3255</td>
#       <td id="T_80e58_row4_col5" class="data row4 col5" >0.2869</td>
#       <td id="T_80e58_row4_col6" class="data row4 col6" >0.4092</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_80e58_row5_col0" class="data row5 col0" >0.8044</td>
#       <td id="T_80e58_row5_col1" class="data row5 col1" >0.9553</td>
#       <td id="T_80e58_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_80e58_row5_col3" class="data row5 col3" >0.1429</td>
#       <td id="T_80e58_row5_col4" class="data row5 col4" >0.2500</td>
#       <td id="T_80e58_row5_col5" class="data row5 col5" >0.2046</td>
#       <td id="T_80e58_row5_col6" class="data row5 col6" >0.3376</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row6" class="row_heading level1 row6" >6</th>
#       <td id="T_80e58_row6_col0" class="data row6 col0" >0.8445</td>
#       <td id="T_80e58_row6_col1" class="data row6 col1" >0.9712</td>
#       <td id="T_80e58_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_80e58_row6_col3" class="data row6 col3" >0.1722</td>
#       <td id="T_80e58_row6_col4" class="data row6 col4" >0.2938</td>
#       <td id="T_80e58_row6_col5" class="data row6 col5" >0.2525</td>
#       <td id="T_80e58_row6_col6" class="data row6 col6" >0.3802</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row7" class="row_heading level1 row7" >7</th>
#       <td id="T_80e58_row7_col0" class="data row7 col0" >0.8541</td>
#       <td id="T_80e58_row7_col1" class="data row7 col1" >0.9711</td>
#       <td id="T_80e58_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_80e58_row7_col3" class="data row7 col3" >0.1814</td>
#       <td id="T_80e58_row7_col4" class="data row7 col4" >0.3071</td>
#       <td id="T_80e58_row7_col5" class="data row7 col5" >0.2670</td>
#       <td id="T_80e58_row7_col6" class="data row7 col6" >0.3925</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row8" class="row_heading level1 row8" >8</th>
#       <td id="T_80e58_row8_col0" class="data row8 col0" >0.8427</td>
#       <td id="T_80e58_row8_col1" class="data row8 col1" >0.9648</td>
#       <td id="T_80e58_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_80e58_row8_col3" class="data row8 col3" >0.1705</td>
#       <td id="T_80e58_row8_col4" class="data row8 col4" >0.2914</td>
#       <td id="T_80e58_row8_col5" class="data row8 col5" >0.2499</td>
#       <td id="T_80e58_row8_col6" class="data row8 col6" >0.3779</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level1_row9" class="row_heading level1 row9" >9</th>
#       <td id="T_80e58_row9_col0" class="data row9 col0" >0.8342</td>
#       <td id="T_80e58_row9_col1" class="data row9 col1" >0.9648</td>
#       <td id="T_80e58_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_80e58_row9_col3" class="data row9 col3" >0.1632</td>
#       <td id="T_80e58_row9_col4" class="data row9 col4" >0.2806</td>
#       <td id="T_80e58_row9_col5" class="data row9 col5" >0.2382</td>
#       <td id="T_80e58_row9_col6" class="data row9 col6" >0.3677</td>
#     </tr>
#     <tr>
#       <th id="T_80e58_level0_row10" class="row_heading level0 row10" rowspan="10">CV-Val</th>
#       <th id="T_80e58_level1_row10" class="row_heading level1 row10" >0</th>
#       <td id="T_80e58_row10_col0" class="data row10 col0" >0.8186</td>
#       <td id="T_80e58_row10_col1" class="data row10 col1" >0.9615</td>
#       <td id="T_80e58_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_80e58_row10_col3" class="data row10 col3" >0.1522</td>
#       <td id="T_80e58_row10_col4" class="data row10 col4" >0.2642</td>
#       <td id="T_80e58_row10_col5" class="data row10 col5" >0.2201</td>
#       <td id="T_80e58_row10_col6" class="data row10 col6" >0.3516</t

# %%
plot_model(lightgbm, plot = 'confusion_matrix', plot_kwargs = {'percent' : True})

# %% [markdown]
# ## Fine turning model

# %%
tuned_lightgbm = tune_model(lightgbm, optimize = 'Prec.')
plot_model(tuned_lightgbm, plot = 'confusion_matrix', plot_kwargs = {'percent' : True})

# %%
boosted_lightgbm = ensemble_model(lightgbm, optimize = 'Prec.')
plot_model(boosted_lightgbm, plot = 'confusion_matrix', plot_kwargs = {'percent' : True})

# %%
bagged_lightgbm = ensemble_model(lightgbm, method = 'Bagging')
plot_model(bagged_lightgbm, plot = 'confusion_matrix', plot_kwargs = {'percent' : True})

# %% [markdown]
# ## Plot model

# %%
plot_model(boosted_lightgbm, plot = 'pr')

# %%
plot_model(boosted_lightgbm, plot = 'threshold')

# %%
plot_model(boosted_lightgbm, plot = 'boundary')

# %% [markdown]
# ## Interprete Model

# %%
# summary plot
interpret_model(lightgbm)

# %%
# correlation plot
interpret_model(lightgbm, plot = 'correlation')

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## evaluate unseen data

# %%
unseen_predictions = predict_model(boosted_lightgbm, data=data_unseen)
cm = confusion_matrix(unseen_predictions["Bankrupt?"], unseen_predictions["Label"], normalize="true")
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e24f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e24f7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e24f7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e24f7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e24f7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e24f7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e24f7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e24f7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e24f7_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e24f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e24f7_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e24f7_row0_col1" class="data row0 col1" >0.8475</td>
#       <td id="T_e24f7_row0_col2" class="data row0 col2" >0.9070</td>
#       <td id="T_e24f7_row0_col3" class="data row0 col3" >0.8636</td>
#       <td id="T_e24f7_row0_col4" class="data row0 col4" >0.1583</td>
#       <td id="T_e24f7_row0_col5" class="data row0 col5" >0.2676</td>
#       <td id="T_e24f7_row0_col6" class="data row0 col6" >0.2254</td>
#       <td id="T_e24f7_row0_col7" class="data row0 col7" >0.3297</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## hotfix

# %%
sns.boxplot(x = unseen_predictions["Label"],
            y = unseen_predictions["Score"],
           hue = unseen_predictions["Bankrupt?"])
# Out:
# <AxesSubplot: xlabel='Label', ylabel='Score'>

# %%
unseen_predictions.loc[(unseen_predictions["Label"] == 0) & (unseen_predictions["Score"] < 0.9), "Filtered_label"] = 1
unseen_predictions.Filtered_label.fillna(unseen_predictions.Label, inplace=True)

# %%
cm = confusion_matrix(unseen_predictions["Bankrupt?"], unseen_predictions["Filtered_label"], normalize="true")
print("Hotfix accuracy: ", accuracy_score(unseen_predictions["Bankrupt?"], unseen_predictions["Filtered_label"]))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# Hotfix accuracy:  0.718475073313783

# %% [markdown]
# ## save model

# %%
save_model(boosted_lightgbm,'saved_models/lightgbm')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[' ROA(C) before '
#                                                            'interest and '
#                                                            'depreciation before '
#                                                            'interest',
#                                                            ' ROA(A) before '
#                                                            'interest and % '
#                                                            'after tax',
#                                                            ' ROA(B) before '
#                                                            'interest and '
#                                                            'depreciation after '
#                                                            'tax',
#                                                            ' Operating Gross '
#                                                            'M...
#                                                                   n_estimators=100,
#                                                                   n_jobs=-1,
#                                                                   num_leaves=31,
#                                                                   objective=None,
#                                                                   random_state=888,
#                                                                   reg_alpha=0.0,
#                                                                   reg_lambda=0.0,
#                                                                   silent='warn',
#                                                                   subsample=1.0,
#                                                                   subsample_for_bin=200000,
#                                                                   subsample_freq=0),
#                                     bootstrap=True, bootstrap_features=False,
#                                     max_features=1.0, max_samples=1.0,
#                                     n_estimators=10, n_jobs=None,
#                                     oob_score=False, random_state=888, verbose=0,
#                                     warm_start=False)]],
#           verbose=False),
#  'saved_models/lightgbm.pkl')
